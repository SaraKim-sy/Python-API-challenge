# %% [markdown]
# # WeatherPy
# ----
#
# ### Observable Trends Based on the Data
# * The Latitude vs. Temperature scatter plot shows that cities that are closer to the equator are high max temperatures. Also, one noticeable thing is that max temperatures of cities in the southern hemisphere roughly range between 40 °F and  110 °F, whereas max temperatures of cities in the northern hemisphere varied in the range of -10 °F and 100 °F. In other words, there are bigger differences between temperatures in the northern hemisphere cities compared to the southern hemisphere cities.
# * Looking at the Latitude vs. Humidity scatter plot, it seems that there is no strong correlation between latitude and humidity.
# * The Latitude vs. Cloudiness scatter plot shows that there is no strong correlation between latitude and cloudiness. There are especially many cities with 0%, 40%, slightly under 80%, and 100% cloudiness, respectively, is also noteworthy.
# * It seems that there is no strong correlation between latitude and wind speed according to the Latitude vs. Wind Speed scatter plot. Most of the cities have wind speeds in the range of 0 mph and 20 mph. Some cities in the northern hemisphere have relatively higher wind speeds compared to cities in the southern hemisphere.
# * Observable trends based on linear regression are the following:
#     * There is a strong negative correlation between temperature and latitude for the cities in the northern hemisphere. The fact that the correlation coefficient was about -0.86 also shows this relationship.
#     * There is a moderate positive correlation between temperature and latitude for the cities in the southern hemisphere. The fact that the correlation coefficient was about 0.68 also shows this relationship.
#     * There is a weak positive correlation between humidity and latitude for the cities in the northern hemisphere. The fact that the correlation coefficient was about 0.33 also shows this relationship.
#     * There seems to be no correlation between humidity and latitude for the cities in the southern hemisphere. The correlation coefficient was about 0.01.
#     * There seems to be a very weak correlation or no significant correlation between cloudiness and latitude, and wind speed and latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = 'http://api.openweathermap.org/data/2.5/weather?'
para = f"&appid={api_key}&units=imperial&q="

url = base_url + para

# %%
# Set up lists to hold response information
cloudiness = []
country_code = []
date = []
humidity = []
cities_lat = []
cities_lng = []
max_temp = []
wind_speed = []
cities_found = []


print('Beginning Data Retrieval')
print('-----------------------------')

# Loop through the list of cities and perform a request for data on each
set_count = 0
set_num = 1

for city in cities:
    query_url = f"{url}{city}"
    response = requests.get(query_url).json()
    
    # Try to grab weather information if they are available
    try:
        cloudiness.append(response['clouds']['all'])
        country_code.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        cities_lat.append(response['coord']['lat'])
        cities_lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        cities_found.append(city)
        
        # Each set will have 50 records
        set_count += 1
        if set_count == 51:
            set_num += 1
            set_count = 1
            # Add a five seconds interval between sets to stay within API query limits
            time.sleep(5)
        
        print(f"Processing Record {set_count} of Set {set_num} | {city}")

    # Handle exceptions for a city not available in the API
    except:
        print("City not found. Skipping...")
        pass
    
print('-----------------------------')
print('Data Retrieval Complete')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | flinders
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | tumen
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | turbat
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | sarangani
# Processing Record 12 of Set 1 | honiara
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | san jose
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | najran
# Processing Record 18 of Set 1 | ratnagiri
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | houma
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 24 of Set 1 | kirchlinteln
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | berlevag
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | kutum
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | billings
# Processing Record 31 of Set 1 | thayetmyo
# Processing Record 32 of Set 1 | denia
# Processing Record 33 of Set 1 | oranjemund
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | yatou
# Processing Record 38 of Set 1 | palenque
# Processing Record 39 of Set 1 | samsun
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | galle
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | virginia beach
# Processing Record 45 of Set 1 | khandyga
# Processing Record 46 of Set 1 | mchinji
# Processing Record 47 of Set 1 | olinda
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | westport
# Processing Record 2 of Set 2 | mayo
# Processing Record 3 of Set 2 | netrakona
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | margate
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | pevek
# City not found. Skipping...
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | gizo
# Processing Record 11 of Set 2 | aginskoye
# Processing Record 12 of Set 2 | samarai
# Processing Record 13 of Set 2 | warrington
# Processing Record 14 of Set 2 | talara
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | coruripe
# Processing Record 18 of Set 2 | walvis bay
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | bathsheba
# City not found. Skipping...
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | kiomboi
# Processing Record 23 of Set 2 | cody
# Processing Record 24 of Set 2 | beringovskiy
# Processing Record 25 of Set 2 | richards bay
# City not found. Skipping...
# Processing Record 26 of Set 2 | port blair
# Processing Record 27 of Set 2 | polunochnoye
# Processing Record 28 of Set 2 | gobabis
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | davila
# City not found. Skipping...
# Processing Record 31 of Set 2 | gorom-gorom
# Processing Record 32 of Set 2 | oussouye
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | hofn
# Processing Record 35 of Set 2 | nouakchott
# City not found. Skipping...
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | kuala lipis
# Processing Record 38 of Set 2 | egvekinot
# Processing Record 39 of Set 2 | verkhniy baskunchak
# Processing Record 40 of Set 2 | comodoro rivadavia
# Processing Record 41 of Set 2 | naze
# City not found. Skipping...
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | huangchuan
# Processing Record 44 of Set 2 | porto velho
# Processing Record 45 of Set 2 | kastamonu
# Processing Record 46 of Set 2 | tobermory
# Processing Record 47 of Set 2 | orotukan
# Processing Record 48 of Set 2 | andenes
# Processing Record 49 of Set 2 | tura
# Processing Record 50 of Set 2 | alamogordo
# City not found. Skipping...
# Processing Record 1 of Set 3 | port macquarie
# City not found. Skipping...
# Processing Record 2 of Set 3 | salekhard
# Processing Record 3 of Set 3 | almeirim
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | caborca
# Processing Record 6 of Set 3 | satipo
# Processing Record 7 of Set 3 | birao
# Processing Record 8 of Set 3 | manokwari
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | broome
# Processing Record 11 of Set 3 | san andres
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | waremme
# Processing Record 14 of Set 3 | tsaratanana
# Processing Record 15 of Set 3 | tallahassee
# Processing Record 16 of Set 3 | harper
# City not found. Skipping...
# Processing Record 17 of Set 3 | zemio
# Processing Record 18 of Set 3 | coffs harbour
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 3 | ercis
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | ponta do sol
# Processing Record 22 of Set 3 | cidreira
# Processing Record 23 of Set 3 | la asuncion
# Processing Record 24 of Set 3 | batagay
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | jhinjhana
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | salair
# City not found. Skipping...
# Processing Record 31 of Set 3 | broken hill
# Processing Record 32 of Set 3 | mar del plata
# Processing Record 33 of Set 3 | baykit
# Processing Record 34 of Set 3 | bidor
# Processing Record 35 of Set 3 | chokurdakh
# Processing Record 36 of Set 3 | vrangel
# Processing Record 37 of Set 3 | praya
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | vila velha
# Processing Record 40 of Set 3 | lapa
# Processing Record 41 of Set 3 | lavrentiya
# Processing Record 42 of Set 3 | sinnamary
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | vetlanda
# Processing Record 45 of Set 3 | southbridge
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | razdolnoye
# Processing Record 1 of Set 4 | havre
# Processing Record 2 of Set 4 | klyuchi
# Processing Record 3 of Set 4 | ossora
# Processing Record 4 of Set 4 | kaitangata
# Processing Record 5 of Set 4 | tual
# City not found. Skipping...
# Processing Record 6 of Set 4 | geraldton
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | makaryev
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | bulgan
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | nelidovo
# Processing Record 14 of Set 4 | mariental
# Processing Record 15 of Set 4 | necochea
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | guerrero negro
# Processing Record 18 of Set 4 | nalut
# Processing Record 19 of Set 4 | peterhead
# Processing Record 20 of Set 4 | makasar
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | teguldet
# Processing Record 24 of Set 4 | aswan
# City not found. Skipping...
# Processing Record 25 of Set 4 | saint-francois
# Processing Record 26 of Set 4 | khilok
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | mogadishu
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | cam ranh
# Processing Record 32 of Set 4 | miyako
# City not found. Skipping...
# Processing Record 33 of Set 4 | saldanha
# Processing Record 34 of Set 4 | alice springs
# City not found. Skipping...
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | wuan
# Processing Record 37 of Set 4 | mahibadhoo
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | kahului
# Processing Record 40 of Set 4 | maicao
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | porto santo
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | bicas
# Processing Record 45 of Set 4 | erzin
# City not found. Skipping...
# Processing Record 46 of Set 4 | dunedin
# Processing Record 47 of Set 4 | jilib
# Processing Record 48 of Set 4 | ritchie
# Processing Record 49 of Set 4 | logrono
# Processing Record 50 of Set 4 | xining
# Processing Record 1 of Set 5 | valle de allende
# Processing Record 2 of Set 5 | solhan
# Processing Record 3 of Set 5 | pahrump
# Processing Record 4 of Set 5 | coahuayana
# Processing Record 5 of Set 5 | mayskiy
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | olafsvik
# Processing Record 9 of Set 5 | vilyuysk
# Processing Record 10 of Set 5 | esperance
# Processing Record 11 of Set 5 | san quintin
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | challans
# Processing Record 14 of Set 5 | namie
# Processing Record 15 of Set 5 | myaundzha
# Processing Record 16 of Set 5 | vuktyl
# Processing Record 17 of Set 5 | dinan
# Processing Record 18 of Set 5 | polyarnyy
# Processing Record 19 of Set 5 | padang
# City not found. Skipping...
# Processing Record 20 of Set 5 | dennery
# Processing Record 21 of Set 5 | lovozero
# Processing Record 22 of Set 5 | inirida
# Processing Record 23 of Set 5 | ucluelet
# Processing Record 24 of Set 5 | mangan
# Processing Record 25 of Set 5 | ler
# City not found. Skipping...
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | luwuk
# Processing Record 28 of Set 5 | honningsvag
# Processing Record 29 of Set 5 | chambas
# Processing Record 30 of Set 5 | cortez
# Processing Record 31 of Set 5 | majene
# Processing Record 32 of Set 5 | koulikoro
# Processing Record 33 of Set 5 | katangli
# Processing Record 34 of Set 5 | rognan
# City not found. Skipping...
# Processing Record 35 of Set 5 | ambovombe
# Processing Record 36 of Set 5 | serafimovich
# Processing Record 37 of Set 5 | sungairaya
# Processing Record 38 of Set 5 | suba
# Processing Record 39 of Set 5 | barcelos
# Processing Record 40 of Set 5 | biak
# Processing Record 41 of Set 5 | dondo
# Processing Record 42 of Set 5 | pangnirtung
# Processing Record 43 of Set 5 | horki
# Processing Record 44 of Set 5 | kathmandu
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | cervo
# Processing Record 48 of Set 5 | ambanja
# Processing Record 49 of Set 5 | bethanien
# City not found. Skipping...
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | ilebo
# City not found. Skipping...
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | saint george
# Processing Record 4 of Set 6 | eenhana
# Processing Record 5 of Set 6 | siocon
# Processing Record 6 of Set 6 | lethem
# Processing Record 7 of Set 6 | sola
# Processing Record 8 of Set 6 | bandarbeyla
# Processing Record 9 of Set 6 | rundu
# Processing Record 10 of Set 6 | santiago del estero
# Processing Record 11 of Set 6 | empangeni
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | thunder bay
# Processing Record 14 of Set 6 | ostrovnoy
# Processing Record 15 of Set 6 | santa maria
# Processing Record 16 of Set 6 | mwandiga
# Processing Record 17 of Set 6 | neiafu
# Processing Record 18 of Set 6 | umm lajj
# Processing Record 19 of Set 6 | toowoomba
# Processing Record 20 of Set 6 | catuday
# City not found. Skipping...
# Processing Record 21 of Set 6 | hambantota
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | mackay
# Processing Record 24 of Set 6 | yilan
# Processing Record 25 of Set 6 | berdigestyakh
# Processing Record 26 of Set 6 | pangkalanbuun
# Processing Record 27 of Set 6 | tessalit
# Processing Record 28 of Set 6 | qaqortoq
# Processing Record 29 of Set 6 | otradnoye
# Processing Record 30 of Set 6 | kurumkan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 6 | kailua
# Processing Record 32 of Set 6 | heishan
# Processing Record 33 of Set 6 | rincon
# Processing Record 34 of Set 6 | cap-chat
# Processing Record 35 of Set 6 | ambulu
# Processing Record 36 of Set 6 | siemiatycze
# Processing Record 37 of Set 6 | ginir
# Processing Record 38 of Set 6 | college
# Processing Record 39 of Set 6 | corn island
# Processing Record 40 of Set 6 | camaqua
# Processing Record 41 of Set 6 | saravan
# Processing Record 42 of Set 6 | vao
# Processing Record 43 of Set 6 | lagoa
# Processing Record 44 of Set 6 | goedereede
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | jibuti
# Processing Record 47 of Set 6 | upata
# Processing Record 48 of Set 6 | boyolangu
# Processing Record 49 of Set 6 | moron
# Processing Record 50 of Set 6 | riyadh
# Processing Record 1 of Set 7 | bonthe
# Processing Record 2 of Set 7 | scarborough
# Processing Record 3 of Set 7 | luena
# City not found. Skipping...
# Processing Record 4 of Set 7 | tilichiki
# Processing Record 5 of Set 7 | kalinovskaya
# Processing Record 6 of Set 7 | sanok
# City not found. Skipping...
# Processing Record 7 of Set 7 | magallon cadre
# Processing Record 8 of Set 7 | mahwa
# Processing Record 9 of Set 7 | svetlyy
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | grindavik
# Processing Record 13 of Set 7 | truckee
# Processing Record 14 of Set 7 | longyearbyen
# Processing Record 15 of Set 7 | acapulco
# Processing Record 16 of Set 7 | asau
# City not found. Skipping...
# Processing Record 17 of Set 7 | vostok
# Processing Record 18 of Set 7 | salalah
# Processing Record 19 of Set 7 | winsum
# Processing Record 20 of Set 7 | taksimo
# Processing Record 21 of Set 7 | miles city
# Processing Record 22 of Set 7 | hamilton
# Processing Record 23 of Set 7 | acari
# Processing Record 24 of Set 7 | sulangan
# Processing Record 25 of Set 7 | callaway
# Processing Record 26 of Set 7 | mount gambier
# Processing Record 27 of Set 7 | lexington
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | marsh harbour
# Processing Record 30 of Set 7 | kimbe
# Processing Record 31 of Set 7 | kununurra
# Processing Record 32 of Set 7 | peniche
# Processing Record 33 of Set 7 | nortelandia
# Processing Record 34 of Set 7 | la massana
# Processing Record 35 of Set 7 | buala
# Processing Record 36 of Set 7 | pontal do parana
# Processing Record 37 of Set 7 | russkaya polyana
# Processing Record 38 of Set 7 | guia lopes da laguna
# Processing Record 39 of Set 7 | hrodna
# Processing Record 40 of Set 7 | chail
# Processing Record 41 of Set 7 | grand gaube
# Processing Record 42 of Set 7 | bilibino
# Processing Record 43 of Set 7 | qasigiannguit
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | ulladulla
# Processing Record 46 of Set 7 | niquero
# Processing Record 47 of Set 7 | prince rupert
# Processing Record 48 of Set 7 | atherton
# Processing Record 49 of Set 7 | takoradi
# Processing Record 50 of Set 7 | porto novo
# Processing Record 1 of Set 8 | poum
# Processing Record 2 of Set 8 | manthani
# Processing Record 3 of Set 8 | nerchinskiy zavod
# Processing Record 4 of Set 8 | barabinsk
# Processing Record 5 of Set 8 | ordzhonikidze
# Processing Record 6 of Set 8 | clovis
# Processing Record 7 of Set 8 | caravelas
# Processing Record 8 of Set 8 | norman wells
# Processing Record 9 of Set 8 | kaeo
# Processing Record 10 of Set 8 | savelugu
# Processing Record 11 of Set 8 | hit
# Processing Record 12 of Set 8 | suntar
# Processing Record 13 of Set 8 | goderich
# Processing Record 14 of Set 8 | champerico
# Processing Record 15 of Set 8 | cobourg
# Processing Record 16 of Set 8 | wlodawa
# Processing Record 17 of Set 8 | saint-pierre
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | banikoara
# Processing Record 20 of Set 8 | porto murtinho
# Processing Record 21 of Set 8 | gavirate
# City not found. Skipping...
# Processing Record 22 of Set 8 | herent
# Processing Record 23 of Set 8 | alta floresta
# Processing Record 24 of Set 8 | moroni
# Processing Record 25 of Set 8 | doha
# Processing Record 26 of Set 8 | nanortalik
# Processing Record 27 of Set 8 | marshfield
# Processing Record 28 of Set 8 | sijunjung
# Processing Record 29 of Set 8 | fort nelson
# Processing Record 30 of Set 8 | urumqi
# Processing Record 31 of Set 8 | kilifarevo
# Processing Record 32 of Set 8 | miguel hidalgo
# Processing Record 33 of Set 8 | chapais
# Processing Record 34 of Set 8 | ishigaki
# City not found. Skipping...
# Processing Record 35 of Set 8 | oudtshoorn
# Processing Record 36 of Set 8 | puerto madryn
# Processing Record 37 of Set 8 | jinchang
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | vaitape
# City not found. Skipping...
# Processing Record 40 of Set 8 | alofi
# City not found. Skipping...
# Processing Record 41 of Set 8 | tabas
# Processing Record 42 of Set 8 | kardailovo
# City not found. Skipping...
# Processing Record 43 of Set 8 | rockhampton
# Processing Record 44 of Set 8 | grants
# City not found. Skipping...
# Processing Record 45 of Set 8 | ribeira grande
# Processing Record 46 of Set 8 | ilhabela
# Processing Record 47 of Set 8 | karakol
# Processing Record 48 of Set 8 | hobyo
# Processing Record 49 of Set 8 | puri
# Processing Record 50 of Set 8 | ibra
# Processing Record 1 of Set 9 | faya
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | amga
# Processing Record 4 of Set 9 | naliya
# Processing Record 5 of Set 9 | lompoc
# Processing Record 6 of Set 9 | sept-iles
# Processing Record 7 of Set 9 | gorontalo
# Processing Record 8 of Set 9 | petatlan
# Processing Record 9 of Set 9 | ketchikan
# Processing Record 10 of Set 9 | koutsouras
# Processing Record 11 of Set 9 | ayacucho
# Processing Record 12 of Set 9 | korla
# Processing Record 13 of Set 9 | port hedland
# Processing Record 14 of Set 9 | harer
# Processing Record 15 of Set 9 | ampanihy
# Processing Record 16 of Set 9 | candelaria
# Processing Record 17 of Set 9 | baoqing
# Processing Record 18 of Set 9 | katherine
# Processing Record 19 of Set 9 | raga
# Processing Record 20 of Set 9 | edgewater
# Processing Record 21 of Set 9 | tateyama
# Processing Record 22 of Set 9 | vadso
# Processing Record 23 of Set 9 | santa cruz
# Processing Record 24 of Set 9 | husavik
# Processing Record 25 of Set 9 | santa ana
# Processing Record 26 of Set 9 | fairbanks
# Processing Record 27 of Set 9 | kalmunai
# Processing Record 28 of Set 9 | axim
# Processing Record 29 of Set 9 | morant bay
# Processing Record 30 of Set 9 | altamira
# Processing Record 31 of Set 9 | luba
# Processing Record 32 of Set 9 | talnakh
# Processing Record 33 of Set 9 | kerman
# Processing Record 34 of Set 9 | leshukonskoye
# Processing Record 35 of Set 9 | maldonado
# Processing Record 36 of Set 9 | rocha
# Processing Record 37 of Set 9 | itanagar
# Processing Record 38 of Set 9 | mandan
# Processing Record 39 of Set 9 | namibe
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | peshkopi
# City not found. Skipping...
# Processing Record 42 of Set 9 | kandla
# Processing Record 43 of Set 9 | kidodi
# Processing Record 44 of Set 9 | sheridan
# Processing Record 45 of Set 9 | kilosa
# Processing Record 46 of Set 9 | codrington
# Processing Record 47 of Set 9 | guymon
# Processing Record 48 of Set 9 | lithakia
# Processing Record 49 of Set 9 | adra
# Processing Record 50 of Set 9 | karratha
# Processing Record 1 of Set 10 | derzhavinsk
# Processing Record 2 of Set 10 | varhaug
# Processing Record 3 of Set 10 | dryden
# Processing Record 4 of Set 10 | zhuhai
# Processing Record 5 of Set 10 | ust-maya
# Processing Record 6 of Set 10 | sabang
# City not found. Skipping...
# Processing Record 7 of Set 10 | sinazongwe
# Processing Record 8 of Set 10 | guanajuato
# Processing Record 9 of Set 10 | yuanping
# Processing Record 10 of Set 10 | usinsk
# Processing Record 11 of Set 10 | flin flon
# Processing Record 12 of Set 10 | marrakesh
# Processing Record 13 of Set 10 | sena madureira
# Processing Record 14 of Set 10 | nelson bay
# Processing Record 15 of Set 10 | sur
# Processing Record 16 of Set 10 | marawi
# Processing Record 17 of Set 10 | merchweiler
# Processing Record 18 of Set 10 | asuncion
# Processing Record 19 of Set 10 | timmendorfer strand
# Processing Record 20 of Set 10 | aberdeen
# Processing Record 21 of Set 10 | keetmanshoop
# Processing Record 22 of Set 10 | bayan
# Processing Record 23 of Set 10 | klaeng
# Processing Record 24 of Set 10 | clarksburg
# Processing Record 25 of Set 10 | cayenne
# City not found. Skipping...
# Processing Record 26 of Set 10 | dingle
# Processing Record 27 of Set 10 | verkhnyaya inta
# Processing Record 28 of Set 10 | san lazaro
# Processing Record 29 of Set 10 | quesnel
# City not found. Skipping...
# Processing Record 30 of Set 10 | general roca
# City not found. Skipping...
# Processing Record 31 of Set 10 | palmer
# Processing Record 32 of Set 10 | terrasini
# City not found. Skipping...
# Processing Record 33 of Set 10 | umm kaddadah
# Processing Record 34 of Set 10 | pochutla
# Processing Record 35 of Set 10 | zeya
# Processing Record 36 of Set 10 | pointe michel
# Processing Record 37 of Set 10 | kuryk
# Processing Record 38 of Set 10 | srednekolymsk
# Processing Record 39 of Set 10 | charters towers
# Processing Record 40 of Set 10 | capanema
# Processing Record 41 of Set 10 | robertsport
# Processing Record 42 of Set 10 | half moon bay
# Processing Record 43 of Set 10 | basoko
# Processing Record 44 of Set 10 | tezu
# Processing Record 45 of Set 10 | eslamshahr
# Processing Record 46 of Set 10 | kugulta
# City not found. Skipping...
# Processing Record 47 of Set 10 | menongue
# Processing Record 48 of Set 10 | norrtalje
# Processing Record 49 of Set 10 | kochubey
# Processing Record 50 of Set 10 | cap malheureux
# Processing Record 1 of Set 11 | mehamn
# Processing Record 2 of Set 11 | hirara
# Processing Record 3 of Set 11 | kirakira
# Processing Record 4 of Set 11 | takab
# Processing Record 5 of Set 11 | turayf
# Processing Record 6 of Set 11 | wenling
# City not found. Skipping...
# Processing Record 7 of Set 11 | bereda
# Processing Record 8 of Set 11 | poshekhonye
# Processing Record 9 of Set 11 | brownsville
# Processing Record 10 of Set 11 | bambanglipuro
# Processing Record 11 of Set 11 | raudeberg
# Processing Record 12 of Set 11 | borovskoy
# Processing Record 13 of Set 11 | mwanza
# Processing Record 14 of Set 11 | tecoanapa
# Processing Record 15 of Set 11 | hualmay
# Processing Record 16 of Set 11 | udachnyy
# Processing Record 17 of Set 11 | shar
# Processing Record 18 of Set 11 | xichang
# Processing Record 19 of Set 11 | santa rosa
# Processing Record 20 of Set 11 | visnes
# Processing Record 21 of Set 11 | mitu
# Processing Record 22 of Set 11 | orlik
# Processing Record 23 of Set 11 | sochi
# Processing Record 24 of Set 11 | along
# Processing Record 25 of Set 11 | lubango
# Processing Record 26 of Set 11 | freudenstadt
# Processing Record 27 of Set 11 | saint anthony
# Processing Record 28 of Set 11 | ayan
# Processing Record 29 of Set 11 | metro
# Processing Record 30 of Set 11 | port hardy
# Processing Record 31 of Set 11 | sarahan
# City not found. Skipping...
# Processing Record 32 of Set 11 | sayat
# Processing Record 33 of Set 11 | winnemucca
# Processing Record 34 of Set 11 | vila franca do campo
# Processing Record 35 of Set 11 | kaliua
# Processing Record 36 of Set 11 | saint-joseph
# Processing Record 37 of Set 11 | ammon
# Processing Record 38 of Set 11 | tulum
# Processing Record 39 of Set 11 | waddan
# Processing Record 40 of Set 11 | manono
# Processing Record 41 of Set 11 | obo
# Processing Record 42 of Set 11 | orange walk
# Processing Record 43 of Set 11 | iqaluit
# City not found. Skipping...
# Processing Record 44 of Set 11 | boca do acre
# Processing Record 45 of Set 11 | saint-augustin
# Processing Record 46 of Set 11 | agadir
# Processing Record 47 of Set 11 | kuusamo
# Processing Record 48 of Set 11 | rabo de peixe
# Processing Record 49 of Set 11 | mapiripan
# Processing Record 50 of Set 11 | am timan
# Processing Record 1 of Set 12 | galesong
# Processing Record 2 of Set 12 | disna
# Processing Record 3 of Set 12 | bacolod
# City not found. Skipping...
# Processing Record 4 of Set 12 | kang
# Processing Record 5 of Set 12 | naftalan
# Processing Record 6 of Set 12 | isangel
# Processing Record 7 of Set 12 | ancud
# Processing Record 8 of Set 12 | loughrea
# City not found. Skipping...
# Processing Record 9 of Set 12 | zyryanka
# Processing Record 10 of Set 12 | tchaourou
# Processing Record 11 of Set 12 | gucheng
# Processing Record 12 of Set 12 | athens
# Processing Record 13 of Set 12 | belmonte
# Processing Record 14 of Set 12 | nome
# Processing Record 15 of Set 12 | banjarmasin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    'City' : cities_found,
    'Cloudiness' : cloudiness,
    'Country' : country_code,
    'Date' : date,
    'Humidity' : humidity,
    'Lat' : cities_lat,
    'Lng' : cities_lng,
    'Max Temp' : max_temp,
    'Wind Speed' : wind_speed
}

weather_df = pd.DataFrame(weather_dict)

# %%
# Display the DataFrame
print(weather_df.count())
weather_df.head()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Lat           565
# Lng           565
# Max Temp      565
# Wind Speed    565
# dtype: int64
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    flinders          91      AU  1604595017        84 -34.58  150.86
# 1  bredasdorp          48      ZA  1604595017        82 -34.53   20.04
# 2     aklavik          40      CA  1604595017        77  68.22 -135.01
# 3       tumen          46      CN  1604595018        76  42.97  129.84
# 4      dikson           0      RU  1604595018        92  73.51   80.55
#
#    Max Temp  Wind Speed
# 0     55.99        5.99
# 1     68.00        8.05
# 2     -2.20        8.05
# 3     41.02        2.04
# 4      0.14        4.90

# %%
# Export the city data into a csv file
weather_df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Max Temp', edgecolors='black', facecolors='lightblue')

plt.title(f'City Latitude vs. Max Temperature ({time.strftime("%m/%d/%y")})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

plt.grid()

plt.savefig("output_data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Humidity', edgecolors='black', facecolors='lightblue')

plt.title(f'City Latitude vs. Humidity ({time.strftime("%m/%d/%y")})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

plt.grid()

plt.savefig("output_data/lat_vs_humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Cloudiness', edgecolors='black', facecolors='lightblue')

plt.title(f'City Latitude vs. Cloudiness ({time.strftime("%m/%d/%y")})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.grid()

plt.savefig("output_data/lat_vs_cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind='scatter', x='Lat', y='Wind Speed', edgecolors='black', facecolors='lightblue')

plt.title(f'City Latitude vs. Wind Speed ({time.strftime("%m/%d/%y")})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

plt.grid()

plt.savefig("output_data/lat_vs_windspeed.png")
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
# Define northern/southern hemisphere
northern_hemisphere_df = weather_df[weather_df['Lat'] > 0]
southern_hemisphere_df = weather_df[weather_df['Lat'] < 0]

northern_hemisphere_df
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 2      aklavik          40      CA  1604595017        77  68.22 -135.01
# 3        tumen          46      CN  1604595018        76  42.97  129.84
# 4       dikson           0      RU  1604595018        92  73.51   80.55
# 5       bethel           1      US  1604595018        51  41.37  -73.41
# 7       turbat           0      PK  1604595018        56  26.00   63.04
# ..         ...         ...     ...         ...       ...    ...     ...
# 558   zyryanka         100      RU  1604595161        91  65.75  150.85
# 559  tchaourou          20      BJ  1604595161        42   8.89    2.60
# 560    gucheng          69      CN  1604595161        67  35.91  111.32
# 561     athens          40      GR  1604595048        55  37.98   23.72
# 563       nome          90      US  1604595161        92  64.50 -165.41
#
#      Max Temp  Wind Speed
# 2       -2.20        8.05
# 3       41.02        2.04
# 4        0.14        4.90
# 5       64.00        9.17
# 7       67.51        2.73
# ..        ...         ...
# 558     -1.28       27.04
# 559     87.53        2.53
# 560     52.00        2.71
# 561     64.40        6.93
# 563     32.00       43.62
#
# [397 rows x 9 columns]

# %%
# Create a function to calculate regression values and creat linear regression plots
def linear_regression_plot(x_values, y_values, x_label, y_label, hemisphere, annotate_point):

    slope, intercept, r, p, std_err = stats.linregress(x_values, y_values)
    
    # Regression values
    regression_values = slope * x_values + intercept
    
    # Create a equation of line    
    eq_line = f"{round(slope, 2)}x + {round(intercept, 2)}"

    # Create a plot
    plt.scatter(x_values, y_values, edgecolors='black', facecolors='lightblue')
    
    plt.plot(x_values, regression_values, color='red')
    plt.annotate(eq_line, annotate_point, color='red', fontsize=16)
    
    plt.title(f'{hemisphere} - {y_label} vs. {x_label} ({time.strftime("%m/%d/%y")})')
    plt.xlabel(f'{x_label}')
    plt.ylabel(f'{y_label}')
               
    plt.grid()

    plt.savefig(f"output_data/{hemisphere}-{y_label}_vs_{x_label}-linear_regression.png")
    plt.show()
    
    print(f'The correlation coefficient is {r}.')
    print(f'r square value is {r**2}.')

# %% [markdown]
# #### Northern Hemisphere - Temperature (F) vs. Latitude

# %%
northern_lat = northern_hemisphere_df['Lat']
northern_temp = northern_hemisphere_df['Max Temp']

lat_label = "Latitude"
temp_label = "Temperature (F)"

northern_hemisphere = "Northern Hemisphere"

linear_regression_plot(northern_lat, northern_temp, lat_label, temp_label, northern_hemisphere, (5, 38))
# Out:
# The correlation coefficient is -0.8554617426877249.
# r square value is 0.7318147932023192.

# %% [markdown]
# #### Southern Hemisphere - Temperature (F) vs. Latitude

# %%
southern_lat = southern_hemisphere_df['Lat']
southern_temp = southern_hemisphere_df['Max Temp']

southern_hemisphere = "Southern Hemisphere"

linear_regression_plot(southern_lat, southern_temp, lat_label, temp_label, southern_hemisphere, (-25, 55))
# Out:
# The correlation coefficient is 0.680060237424483.
# r square value is 0.46248192652584413.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude

# %%
northern_humidity = northern_hemisphere_df['Humidity']

humidity_label = 'Humidity (%)'

linear_regression_plot(northern_lat, northern_humidity, lat_label, humidity_label, northern_hemisphere, (42, 40))
# Out:
# The correlation coefficient is 0.32909927947880396.
# r square value is 0.10830633575346792.

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude

# %%
southern_humidity = southern_hemisphere_df['Humidity']

linear_regression_plot(southern_lat, southern_humidity, lat_label, humidity_label, southern_hemisphere, (-50, 70))
# Out:
# The correlation coefficient is -0.0071699834308839114.
# r square value is 5.140866239914983e-05.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude

# %%
northern_cloudiness = northern_hemisphere_df['Cloudiness']

cloudiness_label = 'Cloudiness (%)'

linear_regression_plot(northern_lat, northern_cloudiness, lat_label, cloudiness_label, northern_hemisphere, (10, 50))
# Out:
# The correlation coefficient is 0.2416653916554524.
# r square value is 0.0584021615239832.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude

# %%
southern_cloudiness = southern_hemisphere_df['Cloudiness']

linear_regression_plot(southern_lat, southern_cloudiness, lat_label, cloudiness_label, southern_hemisphere, (-55, 50))
# Out:
# The correlation coefficient is 0.054037951048436096.
# r square value is 0.002920100153513176.

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
northern_wind_speed = northern_hemisphere_df['Wind Speed']

wind_speed_label = 'Wind Speed (mph)'

linear_regression_plot(northern_lat, northern_wind_speed, lat_label, wind_speed_label, northern_hemisphere, (30, 29))
# Out:
# The correlation coefficient is 0.21456260895294174.
# r square value is 0.046037113160693.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude

# %%
southern_wind_speed = southern_hemisphere_df['Wind Speed']

linear_regression_plot(southern_lat, southern_wind_speed, lat_label, wind_speed_label, southern_hemisphere, (-55, 15))
# Out:
# The correlation coefficient is -0.3511989954361087.
# r square value is 0.12334073439533191.
